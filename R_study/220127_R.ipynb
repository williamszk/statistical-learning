# %%
1 + 1
# Out:
# [1] 2

# %%
my_var = 2

# %%
my_var
# Out:
# [1] 2

# %%
class(my_var)
# Out:
# [1] "numeric"

# %%
my_var <- c(1, 2, 3)

# %%
my_var
# Out:
# [1] 1 2 3

# %%
plot(iris)
# Out:
# plot without title
