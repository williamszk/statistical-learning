# %% [markdown]
# The Julia and R related code are inside the R_study container.
#
# It is not hard to configure Julia and R so that we can use them inside a jupyter notebook.
#
# Let's study this book:
#
# ![image.png](attachment:image.png)

# %%
# https://www.r-project.org/
# https://www.r-project.org/about.html
# https://www.r-project.org/foundation/
# https://contributor.r-project.org/


# https://contributor.r-project.org/rdevguide/
# https://devguide.python.org/
# https://contributor.r-project.org/working-group
# 
# https://github.com/r-devel/r-svn
# https://github.com/cran
# https://github.com/cran/survival
# https://github.com/therneau/survival
# https://karawoo.com/
# https://www.insight-rx.com/

# https://github.com/r-devel
# https://github.com/RConsortium/r-repositories-wg
