# %% [markdown]
# The objective of this notebook is to create a gradient descent algorithm with changing alfa, that is alfa is bigger if the gradient's module is bigger.

# %%
import random
import numpy as np
from numpy import linalg

# %%
def func(x1,x2):
    ff =(x1-3)**2 + (x2-2)**2
    return ff

# %%
def gradFunc(x1,x2):
    g1 = 2*(x1-3)
    g2 = 2*(x2-2)
    return g1, g2

# %%
def grad_optim(func,gradFunc):  
    itmax = 1000 #maximum nº of steps
    normagrad = 1e-3 #minimum norm of gradient
    alfa = 0.1 #rate of learning
    x1,x2 = random.uniform(-2,2),random.uniform(-2,2)
    i = 0
    g = gradFunc(x1,x2)
    norm_g = linalg.norm(g)
    while (norm_g > normagrad) & (i < itmax):
        f = func(x1,x2)
        g = gradFunc(x1,x2)
        norm_g = linalg.norm(g)
        print("Iteration = "+ str(i)+" | gradient norm = "+ str(round(norm_g,3))+
              " | Position = "+"("+str(round(x1,3))+","+ str(round(x2,3))+")")
        i += 1
        x1,x2 = x1-alfa*g[0], x2-alfa*g[1]

    return x1,x2

# %%
grad_optim(func,gradFunc)
# Out:
# Iteration = 0 | gradient norm = 5.462 | Position = (0.441,1.045)
# Iteration = 1 | gradient norm = 4.37 | Position = (0.953,1.236)
# Iteration = 2 | gradient norm = 3.496 | Position = (1.363,1.388)
# Iteration = 3 | gradient norm = 2.797 | Position = (1.69,1.511)
# Iteration = 4 | gradient norm = 2.237 | Position = (1.952,1.609)
# Iteration = 5 | gradient norm = 1.79 | Position = (2.162,1.687)
# Iteration = 6 | gradient norm = 1.432 | Position = (2.329,1.75)
# Iteration = 7 | gradient norm = 1.146 | Position = (2.463,1.8)
# Iteration = 8 | gradient norm = 0.916 | Position = (2.571,1.84)
# Iteration = 9 | gradient norm = 0.733 | Position = (2.657,1.872)
# Iteration = 10 | gradient norm = 0.586 | Position = (2.725,1.897)
# Iteration = 11 | gradient norm = 0.469 | Position = (2.78,1.918)
# Iteration = 12 | gradient norm = 0.375 | Position = (2.824,1.934)
# Iteration = 13 | gradient norm = 0.3 | Position = (2.859,1.947)
# Iteration = 14 | gradient norm = 0.24 | Position = (2.887,1.958)
# Iteration = 15 | gradient norm = 0.192 | Position = (2.91,1.966)
# Iteration = 16 | gradient norm = 0.154 | Position = (2.928,1.973)
# Iteration = 17 | gradient norm = 0.123 | Position = (2.942,1.978)
# Iteration = 18 | gradient norm = 0.098 | Position = (2.954,1.983)
# Iteration = 19 | gradient norm = 0.079 | Position = (2.963,1.986)
# Iteration = 20 | gradient norm = 0.063 | Position = (2.971,1.989)
# Iteration = 21 | gradient norm = 0.05 | Position = (2.976,1.991)
# Iteration = 22 | gradient norm = 0.04 | Position = (2.981,1.993)
# Iteration = 23 | gradient norm = 0.032 | Position = (2.985,1.994)
# Iteration = 24 | gradient norm = 0.026 | Position = (2.988,1.995)
# Iteration = 25 | gradient norm = 0.021 | Position = (2.99,1.996)
# Iteration = 26 | gradient norm = 0.017 | Position = (2.992,1.997)
# Iteration = 27 | gradient norm = 0.013 | Position = (2.994,1.998)
# Iteration = 28 | gradient norm = 0.011 | Position = (2.995,1.998)
# Iteration = 29 | gradient norm = 0.008 | Position = (2.996,1.999)
# Iteration = 30 | gradient norm = 0.007 | Position = (2.997,1.999)
# Iteration = 31 | gradient norm = 0.005 | Position = (2.997,1.999)
# Iteration = 32 | gradient norm = 0.004 | Position = (2.998,1.999)
# Iteration = 33 | gradient norm = 0.003 | Position = (2.998,1.999)
# Iteration = 34 | gradient norm = 0.003 | Position = (2.999,2.0)
# Iteration = 35 | gradient norm = 0.002 | Position = (2.999,2.0)
# Iteration = 36 | gradient norm = 0.002 | Position = (2.999,2.0)
# Iteration = 37 | gradient norm = 0.001 | Position = (2.999,2.0)
# Iteration = 38 | gradient norm = 0.001 | Position = (2.999,2.0)
# Iteration = 39 | gradient norm = 0.001 | Position = (3.0,2.0)
# (2.999659916701209, 1.9998729952370973)

# %% [markdown]
# The following is an adaptative alfa test:

# %%
def grad_optim_ada(func,gradFunc):  
    itmax = 1000 #maximum nº of steps
    normagrad = 1e-3 #minimum norm of gradient
    alfa = 0.1 #rate of learning
    x1,x2 = random.uniform(-2,2),random.uniform(-2,2)
    i = 0
    g = gradFunc(x1,x2)
    norm_g = linalg.norm(g)
    while (norm_g > normagrad) & (i < itmax):
        f = func(x1,x2)
        g = gradFunc(x1,x2)
        norm_g = linalg.norm(g)
        alfa = norm_g/10 #test1 for adaptative alpha
        #alfa = alfa*log(norm_g+100) #test2 for adaptative alpha
        print("Iteration = "+ str(i)+" | gradient norm = "+ str(round(norm_g,3))+
              " | Position = "+"("+str(round(x1,3))+","+ str(round(x2,3))+")"+
              " | Alpha = "+ str(round(alfa,7)))
        i += 1
        x1,x2 = x1-alfa*g[0], x2-alfa*g[1]

    return x1,x2

# %%
grad_optim_ada(func,gradFunc)
# Out:
# Iteration = 0 | gradient norm = 8.724 | Position = (-0.929,0.105) | Alpha = 0.8724359
# Iteration = 1 | gradient norm = 6.499 | Position = (5.927,3.411) | Alpha = 0.649853
# Iteration = 2 | gradient norm = 1.948 | Position = (2.123,1.577) | Alpha = 0.1947648
# Iteration = 3 | gradient norm = 1.189 | Position = (2.465,1.742) | Alpha = 0.1188982
# Iteration = 4 | gradient norm = 0.906 | Position = (2.592,1.803) | Alpha = 0.0906246
# Iteration = 5 | gradient norm = 0.742 | Position = (2.666,1.839) | Alpha = 0.074199
# Iteration = 6 | gradient norm = 0.632 | Position = (2.715,1.863) | Alpha = 0.063188
# Iteration = 7 | gradient norm = 0.552 | Position = (2.751,1.88) | Alpha = 0.0552026
# Iteration = 8 | gradient norm = 0.491 | Position = (2.779,1.893) | Alpha = 0.0491079
# Iteration = 9 | gradient norm = 0.443 | Position = (2.801,1.904) | Alpha = 0.0442847
# Iteration = 10 | gradient norm = 0.404 | Position = (2.818,1.912) | Alpha = 0.0403625
# Iteration = 11 | gradient norm = 0.371 | Position = (2.833,1.919) | Alpha = 0.0371042
# Iteration = 12 | gradient norm = 0.344 | Position = (2.845,1.925) | Alpha = 0.0343508
# Iteration = 13 | gradient norm = 0.32 | Position = (2.856,1.931) | Alpha = 0.0319908
# Iteration = 14 | gradient norm = 0.299 | Position = (2.865,1.935) | Alpha = 0.029944
# Iteration = 15 | gradient norm = 0.282 | Position = (2.873,1.939) | Alpha = 0.0281507
# Iteration = 16 | gradient norm = 0.266 | Position = (2.88,1.942) | Alpha = 0.0265658
# Iteration = 17 | gradient norm = 0.252 | Position = (2.887,1.945) | Alpha = 0.0251543
# Iteration = 18 | gradient norm = 0.239 | Position = (2.892,1.948) | Alpha = 0.0238888
# Iteration = 19 | gradient norm = 0.227 | Position = (2.898,1.951) | Alpha = 0.0227475
# Iteration = 20 | gradient norm = 0.217 | Position = (2.902,1.953) | Alpha = 0.0217126
# Iteration = 21 | gradient norm = 0.208 | Position = (2.906,1.955) | Alpha = 0.0207697
# Iteration = 22 | gradient norm = 0.199 | Position = (2.91,1.957) | Alpha = 0.0199069
# Iteration = 23 | gradient norm = 0.191 | Position = (2.914,1.958) | Alpha = 0.0191144
# Iteration = 24 | gradient norm = 0.184 | Position = (2.917,1.96) | Alpha = 0.0183836
# Iteration = 25 | gradient norm = 0.177 | Position = (2.92,1.962) | Alpha = 0.0177077
# Iteration = 26 | gradient norm = 0.171 | Position = (2.923,1.963) | Alpha = 0.0170806
# Iteration = 27 | gradient norm = 0.165 | Position = (2.926,1.964) | Alpha = 0.0164971
# Iteration = 28 | gradient norm = 0.16 | Position = (2.928,1.965) | Alpha = 0.0159528
# Iteration = 29 | gradient norm = 0.154 | Position = (2.93,1.966) | Alpha = 0.0154438
# Iteration = 30 | gradient norm = 0.15 | Position = (2.933,1.967) | Alpha = 0.0149668
# Iteration = 31 | gradient norm = 0.145 | Position = (2.935,1.968) | Alpha = 0.0145188
# Iteration = 32 | gradient norm = 0.141 | Position = (2.937,1.969) | Alpha = 0.0140972
# Iteration = 33 | gradient norm = 0.137 | Position = (2.938,1.97) | Alpha = 0.0136997
# Iteration = 34 | gradient norm = 0.133 | Position = (2.94,1.971) | Alpha = 0.0133244
# Iteration = 35 | gradient norm = 0.13 | Position = (2.942,1.972) | Alpha = 0.0129693
# Iteration = 36 | gradient norm = 0.126 | Position = (2.943,1.973) | Alpha = 0.0126329
# Iteration = 37 | gradient norm = 0.123 | Position = (2.945,1.973) | Alpha = 0.0123137
# Iteration = 38 | gradient norm = 0.12 | Position = (2.946,1.974) | Alpha = 0.0120105
# Iteration = 39 | gradient norm = 0.117 | Position = (2.947,1.975) | Alpha = 0.0117219
# Iteration = 40 | gradient norm = 0.114 | Position = (2.948,1.975) | Alpha = 0.0114471
# Iteration = 41 | gradient norm = 0.112 | Position = (2.95,1.976) | Alpha = 0.0111851
# Iteration = 42 | gradient norm = 0.109 | Position = (2.951,1.976) | Alpha = 0.0109349
# Iteration = 43 | gradient norm = 0.107 | Position = (2.952,1.977) | Alpha = 0.0106957
# Iteration = 44 | gradient norm = 0.105 | Position = (2.953,1.977) | Alpha = 0.0104669
# Iteration = 45 | gradient norm = 0.102 | Position = (2.954,1.978) | Alpha = 0.0102478
# Iteration = 46 | gradient norm = 0.1 | Position = (2.955,1.978) | Alpha = 0.0100378
# Iteration = 47 | gradient norm = 0.098 | Position = (2.956,1.979) | Alpha = 0.0098363
# Iteration = 48 | gradient norm = 0.096 | Position = (2.957,1.979) | Alpha = 0.0096428
# Iteration = 49 | gradient norm = 0.095 | Position = (2.957,1.979) | Alpha = 0.0094568
# Iteration = 50 | gradient norm = 0.093 | Position = (2.958,1.98) | Alpha = 0.0092779
# Iteration = 51 | gradient norm = 0.091 | Position = (2.959,1.98) | Alpha = 0.0091058
# Iteration = 52 | gradient norm = 0.089 | Position = (2.96,1.981) | Alpha = 0.0089399
# Iteration = 53 | gradient norm = 0.088 | Position = (2.96,1.981) | Alpha = 0.0087801
# Iteration = 54 | gradient norm = 0.086 | Position = (2.961,1.981) | Alpha = 0.0086259
# Iteration = 55 | gradient norm = 0.085 | Position = (2.962,1.982) | Alpha = 0.0084771
# Iteration = 56 | gradient norm = 0.083 | Position = (2.962,1.982) | Alpha = 0.0083334
# Iteration = 57 | gradient norm = 0.082 | Position = (2.963,1.982) | Alpha = 0.0081945
# Iteration = 58 | gradient norm = 0.081 | Position = (2.964,1.982) | Alpha = 0.0080602
# Iteration = 59 | gradient norm = 0.079 | Position = (2.964,1.983) | Alpha = 0.0079303
# Iteration = 60 | gradient norm = 0.078 | Position = (2.965,1.983) | Alpha = 0.0078045
# Iteration = 61 | gradient norm = 0.077 | Position = (2.965,1.983) | Alpha = 0.0076827
# Iteration = 62 | gradient norm = 0.076 | Position = (2.966,1.984) | Alpha = 0.0075646
# Iteration = 63 | gradient norm = 0.075 | Position = (2.966,1.984) | Alpha = 0.0074502
# Iteration = 64 | gradient norm = 0.073 | Position = (2.967,1.984) | Alpha = 0.0073392
# Iteration = 65 | gradient norm = 0.072 | Position = (2.967,1.984) | Alpha = 0.0072314
# Iteration = 66 | gradient norm = 0.071 | Position = (2.968,1.985) | Alpha = 0.0071268
# Iteration = 67 | gradient norm = 0.07 | Position = (2.968,1.985) | Alpha = 0.0070253
# Iteration = 68 | gradient norm = 0.069 | Position = (2.969,1.985) | Alpha = 0.0069265
# Iteration = 69 | gradient norm = 0.068 | Position = (2.969,1.985) | Alpha = 0.0068306
# Iteration = 70 | gradient norm = 0.067 | Position = (2.97,1.985) | Alpha = 0.0067373
# Iteration = 71 | gradient norm = 0.066 | Position = (2.97,1.986) | Alpha = 0.0066465
# Iteration = 72 | gradient norm = 0.066 | Position = (2.97,1.986) | Alpha = 0.0065581
# Iteration = 73 | gradient norm = 0.065 | Position = (2.971,1.986) | Alpha = 0.0064721
# Iteration = 74 | gradient norm = 0.064 | Position = (2.971,1.986) | Alpha = 0.0063883
# Iteration = 75 | gradient norm = 0.063 | Position = (2.972,1.986) | Alpha = 0.0063067
# Iteration = 76 | gradient norm = 0.062 | Position = (2.972,1.986) | Alpha = 0.0062272
# Iteration = 77 | gradient norm = 0.061 | Position = (2.972,1.987) | Alpha = 0.0061496
# Iteration = 78 | gradient norm = 0.061 | Position = (2.973,1.987) | Alpha = 0.006074
# Iteration = 79 | gradient norm = 0.06 | Position = (2.973,1.987) | Alpha = 0.0060002
# Iteration = 80 | gradient norm = 0.059 | Position = (2.973,1.987) | Alpha = 0.0059282
# Iteration = 81 | gradient norm = 0.059 | Position = (2.974,1.987) | Alpha = 0.0058579
# Iteration = 82 | gradient norm = 0.058 | Position = (2.974,1.987) | Alpha = 0.0057893
# Iteration = 83 | gradient norm = 0.057 | Position = (2.974,1.988) | Alpha = 0.0057222
# Iteration = 84 | gradient norm = 0.057 | Position = (2.975,1.988) | Alpha = 0.0056568
# Iteration = 85 | gradient norm = 0.056 | Position = (2.975,1.988) | Alpha = 0.0055928
# Iteration = 86 | gradient norm = 0.055 | Position = (2.975,1.988) | Alpha = 0.0055302
# Iteration = 87 | gradient norm = 0.055 | Position = (2.975,1.988) | Alpha = 0.005469
# Iteration = 88 | gradient norm = 0.054 | Position = (2.976,1.988) | Alpha = 0.0054092
# Iteration = 89 | gradient norm = 0.054 | Position = (2.976,1.988) | Alpha = 0.0053507
# Iteration = 90 | gradient norm = 0.053 | Position = (2.976,1.989) | Alpha = 0.0052934
# Iteration = 91 | gradient norm = 0.052 | Position = (2.976,1.989) | Alpha = 0.0052374
# Iteration = 92 | gradient norm = 0.052 | Position = (2.977,1.989) | Alpha = 0.0051825
# Iteration = 93 | gradient norm = 0.051 | Position = (2.977,1.989) | Alpha = 0.0051288
# Iteration = 94 | gradient norm = 0.051 | Position = (2.977,1.989) | Alpha = 0.0050762
# Iteration = 95 | gradient norm = 0.05 | Position = (2.977,1.989) | Alpha = 0.0050247
# Iteration = 96 | gradient norm = 0.05 | Position = (2.978,1.989) | Alpha = 0.0049742
# Iteration = 97 | gradient norm = 0.049 | Position = (2.978,1.989) | Alpha = 0.0049247
# Iteration = 98 | gradient norm = 0.049 | Position = (2.978,1.989) | Alpha = 0.0048762
# Iteration = 99 | gradient norm = 0.048 | Position = (2.978,1.99) | Alpha = 0.0048286
# Iteration = 100 | gradient norm = 0.048 | Position = (2.978,1.99) | Alpha = 0.004782
# Iteration = 101 | gradient norm = 0.047 | Position = (2.979,1.99) | Alpha = 0.0047363
# Iteration = 102 | gradient norm = 0.047 | Position = (2.979,1.99) | Alpha = 0.0046914
# Iteration = 103 | gradient norm = 0.046 | Position = (2.979,1.99) | Alpha = 0.0046474
# Iteration = 104 | gradient norm = 0.046 | Position = (2.979,1.99) | Alpha = 0.0046042
# Iteration = 105 | gradient norm = 0.046 | Position = (2.979,1.99) | Alpha = 0.0045618
# Iteration = 106 | gradient norm = 0.045 | Position = (2.98,1.99) | Alpha = 0.0045202
# Iteration = 107 | gradient norm = 0.045 | Position = (2.98,1.99) | Alpha = 0.0044793
# Iteration = 108 | gradient norm = 0.044 | Position = (2.98,1.99) | Alpha = 0.0044392
# Iteration = 109 | gradient norm = 0.044 | Position = (2.98,1.99) | Alpha = 0.0043998
# Iteration = 110 | gradient norm = 0.044 | Position = (2.98,1.991) | Alpha = 0.004361
# Iteration = 111 | gradient norm = 0.043 | Position = (2.981,1.991) | Alpha = 0.004323
# Iteration = 112 | gradient norm = 0.043 | Position = (2.981,1.991) | Alpha = 0.0042856
# Iteration = 113 | gradient norm = 0.042 | Position = (2.981,1.991) | Alpha = 0.0042489
# Iteration = 114 | gradient norm = 0.042 | Position = (2.981,1.991) | Alpha = 0.0042128
# Iteration = 115 | gradient norm = 0.042 | Position = (2.981,1.991) | Alpha = 0.0041773
# Iteration = 116 | gradient norm = 0.041 | Position = (2.981,1.991) | Alpha = 0.0041424
# Iteration = 117 | gradient norm = 0.041 | Position = (2.981,1.991) | Alpha = 0.0041081
# Iteration = 118 | gradient norm = 0.041 | Position = (2.982,1.991) | Alpha = 0.0040743
# Iteration = 119 | gradient norm = 0.04 | Position = (2.982,1.991) | Alpha = 0.0040411
# Iteration = 120 | gradient norm = 0.04 | Position = (2.982,1.991) | Alpha = 0.0040085
# Iteration = 121 | gradient norm = 0.04 | Position = (2.982,1.991) | Alpha = 0.0039763
# Iteration = 122 | gradient norm = 0.039 | Position = (2.982,1.991) | Alpha = 0.0039447
# Iteration = 123 | gradient norm = 0.039 | Position = (2.982,1.991) | Alpha = 0.0039136
# Iteration = 124 | gradient norm = 0.039 | Position = (2.983,1.992) | Alpha = 0.003883
# Iteration = 125 | gradient norm = 0.039 | Position = (2.983,1.992) | Alpha = 0.0038528
# Iteration = 126 | gradient norm = 0.038 | Position = (2.983,1.992) | Alpha = 0.0038231
# Iteration = 127 | gradient norm = 0.038 | Position = (2.983,1.992) | Alpha = 0.0037939
# Iteration = 128 | gradient norm = 0.038 | Position = (2.983,1.992) | Alpha = 0.0037651
# Iteration = 129 | gradient norm = 0.037 | Position = (2.983,1.992) | Alpha = 0.0037367
# Iteration = 130 | gradient norm = 0.037 | Position = (2.983,1.992) | Alpha = 0.0037088
# Iteration = 131 | gradient norm = 0.037 | Position = (2.983,1.992) | Alpha = 0.0036813
# Iteration = 132 | gradient norm = 0.037 | Position = (2.984,1.992) | Alpha = 0.0036542
# Iteration = 133 | gradient norm = 0.036 | Position = (2.984,1.992) | Alpha = 0.0036275
# Iteration = 134 | gradient norm = 0.036 | Position = (2.984,1.992) | Alpha = 0.0036012
# Iteration = 135 | gradient norm = 0.036 | Position = (2.984,1.992) | Alpha = 0.0035752
# Iteration = 136 | gradient norm = 0.035 | Position = (2.984,1.992) | Alpha = 0.0035497
# Iteration = 137 | gradient norm = 0.035 | Position = (2.984,1.992) | Alpha = 0.0035245
# Iteration = 138 | gradient norm = 0.035 | Position = (2.984,1.992) | Alpha = 0.0034996
# Iteration = 139 | gradient norm = 0.035 | Position = (2.984,1.992) | Alpha = 0.0034751
# Iteration = 140 | gradient norm = 0.035 | Position = (2.984,1.993) | Alpha = 0.003451
# Iteration = 141 | gradient norm = 0.034 | Position = (2.985,1.993) | Alpha = 0.0034272
# Iteration = 142 | gradient norm = 0.034 | Position = (2.985,1.993) | Alpha = 0.0034037
# Iteration = 143 | gradient norm = 0.034 | Position = (2.985,1.993) | Alpha = 0.0033805
# Iteration = 144 | gradient norm = 0.034 | Position = (2.985,1.993) | Alpha = 0.0033576
# Iteration = 145 | gradient norm = 0.033 | Position = (2.985,1.993) | Alpha = 0.0033351
# Iteration = 146 | gradient norm = 0.033 | Position = (2.985,1.993) | Alpha = 0.0033129
# Iteration = 147 | gradient norm = 0.033 | Position = (2.985,1.993) | Alpha = 0.0032909
# Iteration = 148 | gradient norm = 0.033 | Position = (2.985,1.993) | Alpha = 0.0032692
# Iteration = 149 | gradient norm = 0.032 | Position = (2.985,1.993) | Alpha = 0.0032479
# Iteration = 150 | gradient norm = 0.032 | Position = (2.985,1.993) | Alpha = 0.0032268
# Iteration = 151 | gradient norm = 0.032 | Position = (2.986,1.993) | Alpha = 0.0032059
# Iteration = 152 | gradient norm = 0.032 | Position = (2.986,1.993) | Alpha = 0.0031854
# Iteration = 153 | gradient norm = 0.032 | Position = (2.986,1.993) | Alpha = 0.0031651
# Iteration = 154 | gradient norm = 0.031 | Position = (2.986,1.993) | Alpha = 0.0031451
# Iteration = 155 | gradient norm = 0.031 | Position = (2.986,1.993) | Alpha = 0.0031253
# Iteration = 156 | gradient norm = 0.031 | Position = (2.986,1.993) | Alpha = 0.0031057
# Iteration = 157 | gradient norm = 0.031 | Position = (2.986,1.993) | Alpha = 0.0030865
# Iteration = 158 | gradient norm = 0.031 | Position = (2.986,1.993) | Alpha = 0.0030674
# Iteration = 159 | gradient norm = 0.03 | Position = (2.986,1.993) | Alpha = 0.0030486
# Iteration = 160 | gradient norm = 0.03 | Position = (2.986,1.993) | Alpha = 0.00303
# Iteration = 161 | gradient norm = 0.03 | Position = (2.986,1.993) | Alpha = 0.0030116
# Iteration = 162 | gradient norm = 0.03 | Position = (2.987,1.993) | Alpha = 0.0029935
# Iteration = 163 | gradient norm = 0.03 | Position = (2.987,1.994) | Alpha = 0.0029756
# Iteration = 164 | gradient norm = 0.03 | Position = (2.987,1.994) | Alpha = 0.0029579
# Iteration = 165 | gradient norm = 0.029 | Position = (2.987,1.994) | Alpha = 0.0029404
# Iteration = 166 | gradient norm = 0.029 | Position = (2.987,1.994) | Alpha = 0.0029231
# Iteration = 167 | gradient norm = 0.029 | Position = (2.987,1.994) | Alpha = 0.002906
# Iteration = 168 | gradient norm = 0.029 | Position = (2.987,1.994) | Alpha = 0.0028891
# Iteration = 169 | gradient norm = 0.029 | Position = (2.987,1.994) | Alpha = 0.0028724
# Iteration = 170 | gradient norm = 0.029 | Position = (2.987,1.994) | Alpha = 0.0028559
# Iteration = 171 | gradient norm = 0.028 | Position = (2.987,1.994) | Alpha = 0.0028396
# Iteration = 172 | gradient norm = 0.028 | Position = (2.987,1.994) | Alpha = 0.0028235
# Iteration = 173 | gradient norm = 0.028 | Position = (2.987,1.994) | Alpha = 0.0028075
# Iteration = 174 | gradient norm = 0.028 | Position = (2.987,1.994) | Alpha = 0.0027918
# Iteration = 175 | gradient norm = 0.028 | Position = (2.987,1.994) | Alpha = 0.0027762
# Iteration = 176 | gradient norm = 0.028 | Position = (2.988,1.994) | Alpha = 0.0027608
# Iteration = 177 | gradient norm = 0.027 | Position = (2.988,1.994) | Alpha = 0.0027455
# Iteration = 178 | gradient norm = 0.027 | Position = (2.988,1.994) | Alpha = 0.0027304
# Iteration = 179 | gradient norm = 0.027 | Position = (2.988,1.994) | Alpha = 0.0027155
# Iteration = 180 | gradient norm = 0.027 | Position = (2.988,1.994) | Alpha = 0.0027008
# Iteration = 181 | gradient norm = 0.027 | Position = (2.988,1.994) | Alpha = 0.0026862
# Iteration = 182 | gradient norm = 0.027 | Position = (2.988,1.994) | Alpha = 0.0026718
# Iteration = 183 | gradient norm = 0.027 | Position = (2.988,1.994) | Alpha = 0.0026575
# Iteration = 184 | gradient norm = 0.026 | Position = (2.988,1.994) | Alpha = 0.0026434
# Iteration = 185 | gradient norm = 0.026 | Position = (2.988,1.994) | Alpha = 0.0026294
# Iteration = 186 | gradient norm = 0.026 | Position = (2.988,1.994) | Alpha = 0.0026156
# Iteration = 187 | gradient norm = 0.026 | Position = (2.988,1.994) | Alpha = 0.0026019
# Iteration = 188 | gradient norm = 0.026 | Position = (2.988,1.994) | Alpha = 0.0025883
# Iteration = 189 | gradient norm = 0.026 | Position = (2.988,1.994) | Alpha = 0.0025749
# Iteration = 190 | gradient norm = 0.026 | Position = (2.988,1.994) | Alpha = 0.0025617
# Iteration = 191 | gradient norm = 0.025 | Position = (2.989,1.994) | Alpha = 0.0025485
# Iteration = 192 | gradient norm = 0.025 | Position = (2.989,1.994) | Alpha = 0.0025356
# Iteration = 193 | gradient norm = 0.025 | Position = (2.989,1.995) | Alpha = 0.0025227
# Iteration = 194 | gradient norm = 0.025 | Position = (2.989,1.995) | Alpha = 0.00251
# Iteration = 195 | gradient norm = 0.025 | Position = (2.989,1.995) | Alpha = 0.0024974
# Iteration = 196 | gradient norm = 0.025 | Position = (2.989,1.995) | Alpha = 0.0024849
# Iteration = 197 | gradient norm = 0.025 | Position = (2.989,1.995) | Alpha = 0.0024725
# Iteration = 198 | gradient norm = 0.025 | Position = (2.989,1.995) | Alpha = 0.0024603
# Iteration = 199 | gradient norm = 0.024 | Position = (2.989,1.995) | Alpha = 0.0024482
# Iteration = 200 | gradient norm = 0.024 | Position = (2.989,1.995) | Alpha = 0.0024362
# Iteration = 201 | gradient norm = 0.024 | Position = (2.989,1.995) | Alpha = 0.0024244
# Iteration = 202 | gradient norm = 0.024 | Position = (2.989,1.995) | Alpha = 0.0024126
# Iteration = 203 | gradient norm = 0.024 | Position = (2.989,1.995) | Alpha = 0.002401
# Iteration = 204 | gradient norm = 0.024 | Position = (2.989,1.995) | Alpha = 0.0023894
# Iteration = 205 | gradient norm = 0.024 | Position = (2.989,1.995) | Alpha = 0.002378
# Iteration = 206 | gradient norm = 0.024 | Position = (2.989,1.995) | Alpha = 0.0023667
# Iteration = 207 | gradient norm = 0.024 | Position = (2.989,1.995) | Alpha = 0.0023555
# Iteration = 208 | gradient norm = 0.023 | Position = (2.989,1.995) | Alpha = 0.0023444
# Iteration = 209 | gradient norm = 0.023 | Position = (2.989,1.995) | Alpha = 0.0023334
# Iteration = 210 | gradient norm = 0.023 | Position = (2.99,1.995) | Alpha = 0.0023225
# Iteration = 211 | gradient norm = 0.023 | Position = (2.99,1.995) | Alpha = 0.0023117
# Iteration = 212 | gradient norm = 0.023 | Position = (2.99,1.995) | Alpha = 0.002301
# Iteration = 213 | gradient norm = 0.023 | Position = (2.99,1.995) | Alpha = 0.0022905
# Iteration = 214 | gradient norm = 0.023 | Position = (2.99,1.995) | Alpha = 0.00228
# Iteration = 215 | gradient norm = 0.023 | Position = (2.99,1.995) | Alpha = 0.0022696
# Iteration = 216 | gradient norm = 0.023 | Position = (2.99,1.995) | Alpha = 0.0022593
# Iteration = 217 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.0022491
# Iteration = 218 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.0022389
# Iteration = 219 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.0022289
# Iteration = 220 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.002219
# Iteration = 221 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.0022091
# Iteration = 222 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.0021994
# Iteration = 223 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.0021897
# Iteration = 224 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.0021801
# Iteration = 225 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.0021706
# Iteration = 226 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.0021612
# Iteration = 227 | gradient norm = 0.022 | Position = (2.99,1.995) | Alpha = 0.0021518
# Iteration = 228 | gradient norm = 0.021 | Position = (2.99,1.995) | Alpha = 0.0021426
# Iteration = 229 | gradient norm = 0.021 | Position = (2.99,1.995) | Alpha = 0.0021334
# Iteration = 230 | gradient norm = 0.021 | Position = (2.99,1.995) | Alpha = 0.0021243
# Iteration = 231 | gradient norm = 0.021 | Position = (2.99,1.995) | Alpha = 0.0021153
# Iteration = 232 | gradient norm = 0.021 | Position = (2.991,1.995) | Alpha = 0.0021063
# Iteration = 233 | gradient norm = 0.021 | Position = (2.991,1.995) | Alpha = 0.0020974
# Iteration = 234 | gradient norm = 0.021 | Position = (2.991,1.995) | Alpha = 0.0020886
# Iteration = 235 | gradient norm = 0.021 | Position = (2.991,1.995) | Alpha = 0.0020799
# Iteration = 236 | gradient norm = 0.021 | Position = (2.991,1.996) | Alpha = 0.0020713
# Iteration = 237 | gradient norm = 0.021 | Position = (2.991,1.996) | Alpha = 0.0020627
# Iteration = 238 | gradient norm = 0.021 | Position = (2.991,1.996) | Alpha = 0.0020542
# Iteration = 239 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0020457
# Iteration = 240 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0020374
# Iteration = 241 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0020291
# Iteration = 242 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0020208
# Iteration = 243 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0020127
# Iteration = 244 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0020046
# Iteration = 245 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0019965
# Iteration = 246 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0019886
# Iteration = 247 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0019806
# Iteration = 248 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0019728
# Iteration = 249 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.001965
# Iteration = 250 | gradient norm = 0.02 | Position = (2.991,1.996) | Alpha = 0.0019573
# Iteration = 251 | gradient norm = 0.019 | Position = (2.991,1.996) | Alpha = 0.0019496
# Iteration = 252 | gradient norm = 0.019 | Position = (2.991,1.996) | Alpha = 0.001942
# Iteration = 253 | gradient norm = 0.019 | Position = (2.991,1.996) | Alpha = 0.0019345
# Iteration = 254 | gradient norm = 0.019 | Position = (2.991,1.996) | Alpha = 0.001927
# Iteration = 255 | gradient norm = 0.019 | Position = (2.991,1.996) | Alpha = 0.0019196
# Iteration = 256 | gradient norm = 0.019 | Position = (2.991,1.996) | Alpha = 0.0019122
# Iteration = 257 | gradient norm = 0.019 | Position = (2.991,1.996) | Alpha = 0.0019049
# Iteration = 258 | gradient norm = 0.019 | Position = (2.991,1.996) | Alpha = 0.0018976
# Iteration = 259 | gradient norm = 0.019 | Position = (2.991,1.996) | Alpha = 0.0018904
# Iteration = 260 | gradient norm = 0.019 | Position = (2.992,1.996) | Alpha = 0.0018833
# Iteration = 261 | gradient norm = 0.019 | Position = (2.992,1.996) | Alpha = 0.0018762
# Iteration = 262 | gradient norm = 0.019 | Position = (2.992,1.996) | Alpha = 0.0018692
# Iteration = 263 | gradient norm = 0.019 | Position = (2.992,1.996) | Alpha = 0.0018622
# Iteration = 264 | gradient norm = 0.019 | Position = (2.992,1.996) | Alpha = 0.0018552
# Iteration = 265 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0018483
# Iteration = 266 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0018415
# Iteration = 267 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0018347
# Iteration = 268 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.001828
# Iteration = 269 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0018213
# Iteration = 270 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0018147
# Iteration = 271 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0018081
# Iteration = 272 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0018016
# Iteration = 273 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0017951
# Iteration = 274 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0017886
# Iteration = 275 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0017822
# Iteration = 276 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0017759
# Iteration = 277 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0017696
# Iteration = 278 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0017633
# Iteration = 279 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0017571
# Iteration = 280 | gradient norm = 0.018 | Position = (2.992,1.996) | Alpha = 0.0017509
# Iteration = 281 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0017448
# Iteration = 282 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0017387
# Iteration = 283 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0017326
# Iteration = 284 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0017266
# Iteration = 285 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0017207
# Iteration = 286 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0017148
# Iteration = 287 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0017089
# Iteration = 288 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.001703
# Iteration = 289 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0016972
# Iteration = 290 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0016915
# Iteration = 291 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0016857
# Iteration = 292 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0016801
# Iteration = 293 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0016744
# Iteration = 294 | gradient norm = 0.017 | Position = (2.992,1.996) | Alpha = 0.0016688
# Iteration = 295 | gradient norm = 0.017 | Position = (2.993,1.996) | Alpha = 0.0016632
# Iteration = 296 | gradient norm = 0.017 | Position = (2.993,1.996) | Alpha = 0.0016577
# Iteration = 297 | gradient norm = 0.017 | Position = (2.993,1.996) | Alpha = 0.0016522
# Iteration = 298 | gradient norm = 0.016 | Position = (2.993,1.996) | Alpha = 0.0016468
# Iteration = 299 | gradient norm = 0.016 | Position = (2.993,1.996) | Alpha = 0.0016413
# Iteration = 300 | gradient norm = 0.016 | Position = (2.993,1.996) | Alpha = 0.0016359
# Iteration = 301 | gradient norm = 0.016 | Position = (2.993,1.996) | Alpha = 0.0016306
# Iteration = 302 | gradient norm = 0.016 | Position = (2.993,1.996) | Alpha = 0.0016253
# Iteration = 303 | gradient norm = 0.016 | Position = (2.993,1.996) | Alpha = 0.00162
# Iteration = 304 | gradient norm = 0.016 | Position = (2.993,1.996) | Alpha = 0.0016147
# Iteration = 305 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.0016095
# Iteration = 306 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.0016043
# Iteration = 307 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.0015992
# Iteration = 308 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.0015941
# Iteration = 309 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.001589
# Iteration = 310 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.0015839
# Iteration = 311 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.0015789
# Iteration = 312 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.0015739
# Iteration = 313 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.001569
# Iteration = 314 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.0015641
# Iteration = 315 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.0015592
# Iteration = 316 | gradient norm = 0.016 | Position = (2.993,1.997) | Alpha = 0.0015543
# Iteration = 317 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015495
# Iteration = 318 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015447
# Iteration = 319 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015399
# Iteration = 320 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015352
# Iteration = 321 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015304
# Iteration = 322 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015258
# Iteration = 323 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015211
# Iteration = 324 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015165
# Iteration = 325 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015119
# Iteration = 326 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015073
# Iteration = 327 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0015028
# Iteration = 328 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014983
# Iteration = 329 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014938
# Iteration = 330 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014893
# Iteration = 331 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014849
# Iteration = 332 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014805
# Iteration = 333 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014761
# Iteration = 334 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014717
# Iteration = 335 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014674
# Iteration = 336 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014631
# Iteration = 337 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014588
# Iteration = 338 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014545
# Iteration = 339 | gradient norm = 0.015 | Position = (2.993,1.997) | Alpha = 0.0014503
# Iteration = 340 | gradient norm = 0.014 | Position = (2.993,1.997) | Alpha = 0.0014461
# Iteration = 341 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014419
# Iteration = 342 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014378
# Iteration = 343 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014336
# Iteration = 344 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014295
# Iteration = 345 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014254
# Iteration = 346 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014214
# Iteration = 347 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014173
# Iteration = 348 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014133
# Iteration = 349 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014093
# Iteration = 350 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014053
# Iteration = 351 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0014014
# Iteration = 352 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013975
# Iteration = 353 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013936
# Iteration = 354 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013897
# Iteration = 355 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013858
# Iteration = 356 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.001382
# Iteration = 357 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013781
# Iteration = 358 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013743
# Iteration = 359 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013706
# Iteration = 360 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013668
# Iteration = 361 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013631
# Iteration = 362 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013594
# Iteration = 363 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.0013557
# Iteration = 364 | gradient norm = 0.014 | Position = (2.994,1.997) | Alpha = 0.001352
# Iteration = 365 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013483
# Iteration = 366 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013447
# Iteration = 367 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013411
# Iteration = 368 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013375
# Iteration = 369 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013339
# Iteration = 370 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013303
# Iteration = 371 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013268
# Iteration = 372 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013233
# Iteration = 373 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013198
# Iteration = 374 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013163
# Iteration = 375 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013128
# Iteration = 376 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013094
# Iteration = 377 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.001306
# Iteration = 378 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0013025
# Iteration = 379 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012992
# Iteration = 380 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012958
# Iteration = 381 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012924
# Iteration = 382 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012891
# Iteration = 383 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012858
# Iteration = 384 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012825
# Iteration = 385 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012792
# Iteration = 386 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012759
# Iteration = 387 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012726
# Iteration = 388 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012694
# Iteration = 389 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012662
# Iteration = 390 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.001263
# Iteration = 391 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012598
# Iteration = 392 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012566
# Iteration = 393 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012534
# Iteration = 394 | gradient norm = 0.013 | Position = (2.994,1.997) | Alpha = 0.0012503
# Iteration = 395 | gradient norm = 0.012 | Position = (2.994,1.997) | Alpha = 0.0012472
# Iteration = 396 | gradient norm = 0.012 | Position = (2.994,1.997) | Alpha = 0.0012441
# Iteration = 397 | gradient norm = 0.012 | Position = (2.994,1.997) | Alpha = 0.001241
# Iteration = 398 | gradient norm = 0.012 | Position = (2.994,1.997) | Alpha = 0.0012379
# Iteration = 399 | gradient norm = 0.012 | Position = (2.994,1.997) | Alpha = 0.0012348
# Iteration = 400 | gradient norm = 0.012 | Position = (2.994,1.997) | Alpha = 0.0012318
# Iteration = 401 | gradient norm = 0.012 | Position = (2.994,1.997) | Alpha = 0.0012287
# Iteration = 402 | gradient norm = 0.012 | Position = (2.994,1.997) | Alpha = 0.0012257
# Iteration = 403 | gradient norm = 0.012 | Position = (2.994,1.997) | Alpha = 0.0012227
# Iteration = 404 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0012197
# Iteration = 405 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0012167
# Iteration = 406 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0012138
# Iteration = 407 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0012108
# Iteration = 408 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0012079
# Iteration = 409 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.001205
# Iteration = 410 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0012021
# Iteration = 411 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011992
# Iteration = 412 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011963
# Iteration = 413 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011935
# Iteration = 414 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011906
# Iteration = 415 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011878
# Iteration = 416 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.001185
# Iteration = 417 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011821
# Iteration = 418 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011794
# Iteration = 419 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011766
# Iteration = 420 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011738
# Iteration = 421 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.001171
# Iteration = 422 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011683
# Iteration = 423 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011656
# Iteration = 424 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011629
# Iteration = 425 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011602
# Iteration = 426 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011575
# Iteration = 427 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011548
# Iteration = 428 | gradient norm = 0.012 | Position = (2.995,1.997) | Alpha = 0.0011521
# Iteration = 429 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011495
# Iteration = 430 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011468
# Iteration = 431 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011442
# Iteration = 432 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011416
# Iteration = 433 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.001139
# Iteration = 434 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011364
# Iteration = 435 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011338
# Iteration = 436 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011312
# Iteration = 437 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011287
# Iteration = 438 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011261
# Iteration = 439 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011236
# Iteration = 440 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.001121
# Iteration = 441 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011185
# Iteration = 442 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.001116
# Iteration = 443 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011135
# Iteration = 444 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011111
# Iteration = 445 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011086
# Iteration = 446 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011061
# Iteration = 447 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011037
# Iteration = 448 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0011012
# Iteration = 449 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010988
# Iteration = 450 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010964
# Iteration = 451 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.001094
# Iteration = 452 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010916
# Iteration = 453 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010892
# Iteration = 454 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010869
# Iteration = 455 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010845
# Iteration = 456 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010821
# Iteration = 457 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010798
# Iteration = 458 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010775
# Iteration = 459 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010751
# Iteration = 460 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010728
# Iteration = 461 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010705
# Iteration = 462 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010682
# Iteration = 463 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.001066
# Iteration = 464 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010637
# Iteration = 465 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010614
# Iteration = 466 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010592
# Iteration = 467 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010569
# Iteration = 468 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010547
# Iteration = 469 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010525
# Iteration = 470 | gradient norm = 0.011 | Position = (2.995,1.998) | Alpha = 0.0010502
# Iteration = 471 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.001048
# Iteration = 472 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010458
# Iteration = 473 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010437
# Iteration = 474 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010415
# Iteration = 475 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010393
# Iteration = 476 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010371
# Iteration = 477 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.001035
# Iteration = 478 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010329
# Iteration = 479 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010307
# Iteration = 480 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010286
# Iteration = 481 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010265
# Iteration = 482 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010244
# Iteration = 483 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010223
# Iteration = 484 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010202
# Iteration = 485 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010181
# Iteration = 486 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.001016
# Iteration = 487 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.001014
# Iteration = 488 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010119
# Iteration = 489 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010099
# Iteration = 490 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010078
# Iteration = 491 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010058
# Iteration = 492 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010038
# Iteration = 493 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0010018
# Iteration = 494 | gradient norm = 0.01 | Position = (2.995,1.998) | Alpha = 0.0009997
# Iteration = 495 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009977
# Iteration = 496 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009958
# Iteration = 497 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009938
# Iteration = 498 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009918
# Iteration = 499 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009898
# Iteration = 500 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009879
# Iteration = 501 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009859
# Iteration = 502 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.000984
# Iteration = 503 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.000982
# Iteration = 504 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009801
# Iteration = 505 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009782
# Iteration = 506 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009763
# Iteration = 507 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009744
# Iteration = 508 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009725
# Iteration = 509 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009706
# Iteration = 510 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009687
# Iteration = 511 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009668
# Iteration = 512 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009649
# Iteration = 513 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009631
# Iteration = 514 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009612
# Iteration = 515 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009594
# Iteration = 516 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009575
# Iteration = 517 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009557
# Iteration = 518 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009539
# Iteration = 519 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009521
# Iteration = 520 | gradient norm = 0.01 | Position = (2.996,1.998) | Alpha = 0.0009502
# Iteration = 521 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009484
# Iteration = 522 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009466
# Iteration = 523 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009449
# Iteration = 524 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009431
# Iteration = 525 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009413
# Iteration = 526 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009395
# Iteration = 527 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009377
# Iteration = 528 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.000936
# Iteration = 529 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009342
# Iteration = 530 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009325
# Iteration = 531 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009308
# Iteration = 532 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.000929
# Iteration = 533 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009273
# Iteration = 534 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009256
# Iteration = 535 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009239
# Iteration = 536 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009222
# Iteration = 537 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009205
# Iteration = 538 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009188
# Iteration = 539 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009171
# Iteration = 540 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009154
# Iteration = 541 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009137
# Iteration = 542 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.000912
# Iteration = 543 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009104
# Iteration = 544 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009087
# Iteration = 545 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009071
# Iteration = 546 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009054
# Iteration = 547 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009038
# Iteration = 548 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009022
# Iteration = 549 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0009005
# Iteration = 550 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0008989
# Iteration = 551 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0008973
# Iteration = 552 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0008957
# Iteration = 553 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0008941
# Iteration = 554 | gradient norm = 0.009 | Position = (2.996,1.998) | Alpha = 0.0008925
# ...
# Iteration = 817 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0006071
# Iteration = 818 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0006063
# Iteration = 819 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0006056
# Iteration = 820 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0006049
# Iteration = 821 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0006041
# Iteration = 822 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0006034
# Iteration = 823 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0006027
# Iteration = 824 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0006019
# Iteration = 825 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0006012
# Iteration = 826 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0006005
# Iteration = 827 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005998
# Iteration = 828 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005991
# Iteration = 829 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005983
# Iteration = 830 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005976
# Iteration = 831 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005969
# Iteration = 832 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005962
# Iteration = 833 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005955
# Iteration = 834 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005948
# Iteration = 835 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005941
# Iteration = 836 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005934
# Iteration = 837 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005927
# Iteration = 838 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.000592
# Iteration = 839 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005913
# Iteration = 840 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005906
# Iteration = 841 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005899
# Iteration = 842 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005892
# Iteration = 843 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005885
# Iteration = 844 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005878
# Iteration = 845 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005871
# Iteration = 846 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005864
# Iteration = 847 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005857
# Iteration = 848 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.000585
# Iteration = 849 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005843
# Iteration = 850 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005837
# Iteration = 851 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.000583
# Iteration = 852 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005823
# Iteration = 853 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005816
# Iteration = 854 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005809
# Iteration = 855 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005803
# Iteration = 856 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005796
# Iteration = 857 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005789
# Iteration = 858 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005783
# Iteration = 859 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005776
# Iteration = 860 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005769
# Iteration = 861 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005762
# Iteration = 862 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005756
# Iteration = 863 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005749
# Iteration = 864 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005743
# Iteration = 865 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005736
# Iteration = 866 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005729
# Iteration = 867 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005723
# Iteration = 868 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005716
# Iteration = 869 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.000571
# Iteration = 870 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005703
# Iteration = 871 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005697
# Iteration = 872 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.000569
# Iteration = 873 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005684
# Iteration = 874 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005677
# Iteration = 875 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005671
# Iteration = 876 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005664
# Iteration = 877 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005658
# Iteration = 878 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005652
# Iteration = 879 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005645
# Iteration = 880 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005639
# Iteration = 881 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005633
# Iteration = 882 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005626
# Iteration = 883 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.000562
# Iteration = 884 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005614
# Iteration = 885 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005607
# Iteration = 886 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005601
# Iteration = 887 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005595
# Iteration = 888 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005588
# Iteration = 889 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005582
# Iteration = 890 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005576
# Iteration = 891 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.000557
# Iteration = 892 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005564
# Iteration = 893 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005557
# Iteration = 894 | gradient norm = 0.006 | Position = (2.997,1.999) | Alpha = 0.0005551
# Iteration = 895 | gradient norm = 0.006 | Position = (2.998,1.999) | Alpha = 0.0005545
# Iteration = 896 | gradient norm = 0.006 | Position = (2.998,1.999) | Alpha = 0.0005539
# Iteration = 897 | gradient norm = 0.006 | Position = (2.998,1.999) | Alpha = 0.0005533
# Iteration = 898 | gradient norm = 0.006 | Position = (2.998,1.999) | Alpha = 0.0005527
# Iteration = 899 | gradient norm = 0.006 | Position = (2.998,1.999) | Alpha = 0.000552
# Iteration = 900 | gradient norm = 0.006 | Position = (2.998,1.999) | Alpha = 0.0005514
# Iteration = 901 | gradient norm = 0.006 | Position = (2.998,1.999) | Alpha = 0.0005508
# Iteration = 902 | gradient norm = 0.006 | Position = (2.998,1.999) | Alpha = 0.0005502
# Iteration = 903 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005496
# Iteration = 904 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.000549
# Iteration = 905 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005484
# Iteration = 906 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005478
# Iteration = 907 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005472
# Iteration = 908 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005466
# Iteration = 909 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.000546
# Iteration = 910 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005454
# Iteration = 911 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005448
# Iteration = 912 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005442
# Iteration = 913 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005436
# Iteration = 914 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.000543
# Iteration = 915 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005425
# Iteration = 916 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005419
# Iteration = 917 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005413
# Iteration = 918 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005407
# Iteration = 919 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005401
# Iteration = 920 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005395
# Iteration = 921 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005389
# Iteration = 922 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005384
# Iteration = 923 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005378
# Iteration = 924 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005372
# Iteration = 925 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005366
# Iteration = 926 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.000536
# Iteration = 927 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005355
# Iteration = 928 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005349
# Iteration = 929 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005343
# Iteration = 930 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005338
# Iteration = 931 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005332
# Iteration = 932 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005326
# Iteration = 933 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005321
# Iteration = 934 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005315
# Iteration = 935 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005309
# Iteration = 936 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005304
# Iteration = 937 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005298
# Iteration = 938 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005292
# Iteration = 939 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005287
# Iteration = 940 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005281
# Iteration = 941 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005276
# Iteration = 942 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.000527
# Iteration = 943 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005264
# Iteration = 944 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005259
# Iteration = 945 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005253
# Iteration = 946 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005248
# Iteration = 947 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005242
# Iteration = 948 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005237
# Iteration = 949 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005231
# Iteration = 950 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005226
# Iteration = 951 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.000522
# Iteration = 952 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005215
# Iteration = 953 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.000521
# Iteration = 954 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005204
# Iteration = 955 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005199
# Iteration = 956 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005193
# Iteration = 957 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005188
# Iteration = 958 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005183
# Iteration = 959 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005177
# Iteration = 960 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005172
# Iteration = 961 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005166
# Iteration = 962 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005161
# Iteration = 963 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005156
# Iteration = 964 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.000515
# Iteration = 965 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005145
# Iteration = 966 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.000514
# Iteration = 967 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005135
# Iteration = 968 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005129
# Iteration = 969 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005124
# Iteration = 970 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005119
# Iteration = 971 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005114
# Iteration = 972 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005108
# Iteration = 973 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005103
# Iteration = 974 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005098
# Iteration = 975 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005093
# Iteration = 976 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005087
# Iteration = 977 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005082
# Iteration = 978 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005077
# Iteration = 979 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005072
# Iteration = 980 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005067
# Iteration = 981 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005062
# Iteration = 982 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005057
# Iteration = 983 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005051
# Iteration = 984 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005046
# Iteration = 985 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005041
# Iteration = 986 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005036
# Iteration = 987 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005031
# Iteration = 988 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005026
# Iteration = 989 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005021
# Iteration = 990 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005016
# Iteration = 991 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005011
# Iteration = 992 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005006
# Iteration = 993 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0005001
# Iteration = 994 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0004996
# Iteration = 995 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0004991
# Iteration = 996 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0004986
# Iteration = 997 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0004981
# Iteration = 998 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0004976
# Iteration = 999 | gradient norm = 0.005 | Position = (2.998,1.999) | Alpha = 0.0004971
# (2.9977634671679243, 1.9989213717136365)
